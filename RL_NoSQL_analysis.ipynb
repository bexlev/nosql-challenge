# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
import json
import requests
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
food_db = mongo.uk_food

# %%
# review the collections in our database
collections = food_db.command("listCollections")
print(collections)
# Out:
# {'cursor': {'id': 0, 'ns': 'uk_food.$cmd.listCollections', 'firstBatch': [{'name': 'establishments', 'type': 'collection', 'options': {}, 'info': {'readOnly': False, 'uuid': UUID('ebf21394-2a45-4696-b693-a7857d72cd5c')}, 'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_'}}]}, 'ok': 1.0}

# %%
# assign the collection to a variable
collection = food_db.establishments

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# View one document for reference
document = collection.find_one()

pprint(document)
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d17220d1aa1709dbbbe660'),
#  'geocode': {'$map': {'as': 'val',
#                       'in': {'$toDecimal': '$$val'},
#                       'input': '$longitude'},
#              'latitude': None,
#              'longitude': None},
#  'latitude': {'$map': {'as': 'val',
#                        'in': {'$toDecimal': '$$val'},
#                        'input': '$latitude'}},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'longitude': {'$map': {'as': 'val',
#                         'in': {'$toDecimal': '$$val'},
#                         'input': '$longitude'}},
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %%
# Find the establishments with a hygiene score of 20
#Referring to  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

#Checking datatype of  hygiene score
hygiene_type = type(document['scores']['Hygiene'])
print("Hygiene Score Type: ", hygiene_type)

#It is currently int, so can proceed
# Out:
# Hygiene Score Type:  <class 'int'>

# %%
#Generating query
query1 = {'scores.Hygiene': {"$eq": 20}}
documents = collection.find(query1)

#Counting the number of documents returned by the query
doc_count = collection.count_documents(query1)
print("Number of Documents: ", doc_count)
# Out:
# Number of Documents:  41

# %%
# Display the first document in the results using pprint
first_doc = collection.find(query1).limit(1)
pprint(first_doc[0])
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d17220d1aa1709dbbc0192'),
#  'geocode': {'$map': {'as': 'val',
#                       'in': {'$toDecimal': '$$val'},
#                       'input': '$longitude'},
#              'latitude': None,
#              'longitude': None},
#  'latitude': {'$map': {'as': 'val',
#                        'in': {'$toDecimal': '$$val'},
#                        'input': '$latitude'}},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'longitude': {'$map': {'as': 'val',
#                         'in': {'$toDecimal': '$$val'},
#                         'input': '$longitude'}},
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
hygiene_score_20_df = pd.DataFrame(list(documents))
hygiene_score_20_df.set_index("_id")
# Out:
#                            FHRSID  ChangesByServerID LocalAuthorityBusinessID  \
# _id
# 63d17220d1aa1709dbbc0192   110681                  0                     4029
# 63d17220d1aa1709dbbc0513   612039                  0                1970/FOOD
# 63d17220d1aa1709dbbc0820   730933                  0                1698/FOOD
# 63d17220d1aa1709dbbc0a0e   172735                  0             PI/000023858
# 63d17220d1aa1709dbbc0a1b   172953                  0             PI/000024532
# 63d17220d1aa1709dbbc13bc   512854                  0            12/00816/BUTH
# 63d17220d1aa1709dbbc15dd  1537089                  0          22/00224/RESTUN
# 63d17220d1aa1709dbbc2b07   155648                  0              EH/00006058
# 63d17220d1aa1709dbbc2f4a  1012883                  0         17/00110/MIXED/S
# 63d17221d1aa1709dbbc375c   644109                  0                    41811
# 63d17221d1aa1709dbbc37ce   267034                  0           11/00102/MIXED
# 63d17221d1aa1709dbbc3e95   972876                  0          17/00059/FOOD/S
# 63d17221d1aa1709dbbc4752  1417416                  0              21/00350/CP
{'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                                       links  \
# _id
# 63d17220d1aa1709dbbc0192  [{'rel': 'self', 'href': 'https://api.ratings....
# 63d17220d1aa1709dbbc0513  [{'rel': 'self', 'href': 'https://api.ratings....
# 63d17220d1aa1709dbbc0820  [{'rel': 'self', 'href': 'https://api.ratings....
# 63d17220d1aa1709dbbc0a0e  [{'rel': 'self', 'href': 'https://api.ratings....
# 63d17220d1aa1709dbbc0a1b  [{'rel': 'self', 'href': 'https://api.ratings....
# 63d17220d1aa1709dbbc13bc  [{'rel': 'self', 'href': 'https://api.ratings....
# 63d17220d1aa1709dbbc15dd  [{'rel': 'self', 'href': 'https://api.ratings....
# 63d17220d1aa1709dbbc2b07  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17220d1aa1709dbbc2f4a  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc375c  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc37ce  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc3e95  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc4752  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc4d5f  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc50bc  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc562c  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc569c  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc5901  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc5ed7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc648a  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc64a9  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc677e  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc67c0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc68c8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc6989  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc6999  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc6a86  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc6af8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc6d52  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc6d8e  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc6e06  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc6f0f  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc6ffc  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc70a8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc7257  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc73e8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc74cf  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc7845  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc7a3c  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc7c57  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 63d17221d1aa1709dbbc7e4e  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
#                                                                   longitude  \
# _id
# 63d17220d1aa1709dbbc0192  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17220d1aa1709dbbc0513  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17220d1aa1709dbbc0820  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17220d1aa1709dbbc0a0e  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17220d1aa1709dbbc0a1b  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17220d1aa1709dbbc13bc  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17220d1aa1709dbbc15dd  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17220d1aa1709dbbc2b07  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17220d1aa1709dbbc2f4a  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc375c  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc37ce  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc3e95  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc4752  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc4d5f  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc50bc  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc562c  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc569c  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc5901  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc5ed7  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc648a  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc64a9  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc677e  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc67c0  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc68c8  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc6989  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc6999  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc6a86  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc6af8  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc6d52  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc6d8e  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc6e06  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc6f0f  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc6ffc  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc70a8  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc7257  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc73e8  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc74cf  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc7845  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc7a3c  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc7c57  {'$map': {'input': '$longitude', 'as': 'val', ...
# 63d17221d1aa1709dbbc7e4e  {'$map': {'input': '$longitude', 'as': 'val', ...
#
#                                                                    latitude
# _id
# 63d17220d1aa1709dbbc0192  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17220d1aa1709dbbc0513  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17220d1aa1709dbbc0820  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17220d1aa1709dbbc0a0e  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17220d1aa1709dbbc0a1b  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17220d1aa1709dbbc13bc  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17220d1aa1709dbbc15dd  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17220d1aa1709dbbc2b07  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17220d1aa1709dbbc2f4a  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc375c  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc37ce  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc3e95  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc4752  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc4d5f  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc50bc  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc562c  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc569c  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc5901  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc5ed7  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc648a  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc64a9  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc677e  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc67c0  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc68c8  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc6989  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc6999  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc6a86  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc6af8  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc6d52  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc6d8e  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc6e06  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc6f0f  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc6ffc  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc70a8  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc7257  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc73e8  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc74cf  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc7845  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc7a3c  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc7c57  {'$map': {'input': '$latitude', 'as': 'val', '...
# 63d17221d1aa1709dbbc7e4e  {'$map': {'input': '$latitude', 'as': 'val', '...
#
# [41 rows x 29 columns]

# %%
# Display the number of rows in the DataFrame
print(len(hygiene_score_20_df))

# Display the first 10 rows of the DataFrame
hygiene_score_20_df.head(10)
# Out:
# 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  63d17220d1aa1709dbbc0192   110681                  0
# 1  63d17220d1aa1709dbbc0513   612039                  0
# 2  63d17220d1aa1709dbbc0820   730933                  0
# 3  63d17220d1aa1709dbbc0a0e   172735                  0
# 4  63d17220d1aa1709dbbc0a1b   172953                  0
# 5  63d17220d1aa1709dbbc13bc   512854                  0
# 6  63d17220d1aa1709dbbc15dd  1537089                  0
# 7  63d17220d1aa1709dbbc2b07   155648                  0
# 8  63d17220d1aa1709dbbc2f4a  1012883                  0
# 9  63d17221d1aa1709dbbc375c   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
#
#                                              geocode RightToReply  \
# 0  {'$map': {'input': '$longitude', 'as': 'val', ...
# 1  {'$map': {'input': '$longitude', 'as': 'val', ...
# 2  {'$map': {'input': '$longitude', 'as': 'val', ...
# 3  {'$map': {'input': '$longitude', 'as': 'val', ...
# 4  {'$map': {'input': '$longitude', 'as': 'val', ...
# 5  {'$map': {'input': '$longitude', 'as': 'val', ...
# 6  {'$map': {'input': '$longitude', 'as': 'val', ...
# 7  {'$map': {'input': '$longitude', 'as': 'val', ...
# 8  {'$map': {'input': '$longitude', 'as': 'val', ...
# 9  {'$map': {'input': '$longitude', 'as': 'val', ...
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links  \
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
#                                            longitude  \
# 0  {'$map': {'input': '$longitude', 'as': 'val', ...
# 1  {'$map': {'input': '$longitude', 'as': 'val', ...
# 2  {'$map': {'input': '$longitude', 'as': 'val', ...
# 3  {'$map': {'input': '$longitude', 'as': 'val', ...
# 4  {'$map': {'input': '$longitude', 'as': 'val', ...
# 5  {'$map': {'input': '$longitude', 'as': 'val', ...
# 6  {'$map': {'input': '$longitude', 'as': 'val', ...
# 7  {'$map': {'input': '$longitude', 'as': 'val', ...
# 8  {'$map': {'input': '$longitude', 'as': 'val', ...
# 9  {'$map': {'input': '$longitude', 'as': 'val', ...
#
#                                             latitude
# 0  {'$map': {'input': '$latitude', 'as': 'val', '...
# 1  {'$map': {'input': '$latitude', 'as': 'val', '...
# 2  {'$map': {'input': '$latitude', 'as': 'val', '...
# 3  {'$map': {'input': '$latitude', 'as': 'val', '...
# 4  {'$map': {'input': '$latitude', 'as': 'val', '...
# 5  {'$map': {'input': '$latitude', 'as': 'val', '...
# 6  {'$map': {'input': '$latitude', 'as': 'val', '...
# 7  {'$map': {'input': '$latitude', 'as': 'val', '...
# 8  {'$map': {'input': '$latitude', 'as': 'val', '...
# 9  {'$map': {'input': '$latitude', 'as': 'val', '...
#
# [10 rows x 30 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
#Fields: 'RatingValue', city is under  'AddressLine3'

# %%
#Checking field data
ratingval_type = type(document['RatingValue'])
print("RatingValue Type: ", ratingval_type)
# Out:
# RatingValue Type:  <class 'int'>

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query2 = {'RatingValue': {"$gte": '4'}, 'AddressLine3': {"$regex": "London", "$options": "i"}}
documents2 = collection.find(query2)

# Using count_documents to display the number of documents in the result in output
doc_count = collection.count_documents(query2)
print("Number of Documents: ", doc_count)
# Out:
# Number of Documents:  1192

# %%
# Display the first document in the results using pprint
first_doc2 = collection.find(query2).limit(1)
pprint(first_doc2[0])
# Out:
# {'AddressLine1': 'Burger Van',
#  'AddressLine2': 'Wickes',
#  'AddressLine3': 'London Road',
#  'AddressLine4': 'Sittingbourne',
#  'BusinessName': 'Nats Snax',
#  'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  'ChangesByServerID': 0,
#  'Distance': 4618.8604695160675,
#  'FHRSID': 836424,
#  'LocalAuthorityBusinessID': '15/500750/MIXED',
#  'LocalAuthorityCode': '189',
#  'LocalAuthorityEmailAddress': 'EHAdmin@MidKent.gov.uk',
#  'LocalAuthorityName': 'Swale',
#  'LocalAuthorityWebSite': 'http://www.swale.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME10 1NU',
#  'RatingDate': '2022-06-21T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63d17220d1aa1709dbbc06b2'),
#  'geocode': {'$map': {'as': 'val',
#                       'in': {'$toDecimal': '$$val'},
#                       'input': '$longitude'},
#              'latitude': None,
#              'longitude': None},
#  'latitude': {'$map': {'as': 'val',
#                        'in': {'$toDecimal': '$$val'},
#                        'input': '$latitude'}},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/836424',
#             'rel': 'self'}],
#  'longitude': {'$map': {'as': 'val',
#                         'in': {'$toDecimal': '$$val'},
#                         'input': '$longitude'}},
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %%
# Convert the result to a Pandas DataFrame
query2_df = pd.DataFrame(list(documents2))
query2_df.set_index('_id')
query2_df.head()
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  63d17220d1aa1709dbbc06b2   836424                  0
# 1  63d17220d1aa1709dbbc07dc  1009559                  0
# 2  63d17220d1aa1709dbbc1113   632021                  0
# 3  63d17220d1aa1709dbbc1130   959816                  0
# 4  63d17220d1aa1709dbbc1155  1290095                  0
#
#   LocalAuthorityBusinessID                   BusinessName       BusinessType  \
# 0          15/500750/MIXED                      Nats Snax     Mobile caterer
# 1           17/500586/FOOD       Sittingbourne Rugby Club  Pub/bar/nightclub
# 2             PI/000023516                  Welcome House    Caring Premises
# 3          17/500226/MIXED  The Food Warehouse By Iceland  Retailers - other
# 4          20/500534/MIXED                  Home Bargains  Retailers - other
#
#    BusinessTypeID                 AddressLine1             AddressLine2  \
# 0            7846                   Burger Van                   Wickes
# 1            7843      Gore Court Cricket Club           The Grove Park
# 2               5  Welcome House - Leeza Court              Leeza Court
# 3            4613                      Unit 1B  London Road Retail Park
# 4            4613                       Unit 3  London Road Retail Park
#
#     AddressLine3  ...                                             scores  \
# 0    London Road  ...  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
# 1    London Road  ...  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...
# 2  9 London Road  ...  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
# 3    London Road  ...  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...
# 4    London Road  ...  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
#
#   SchemeType                                            geocode RightToReply  \
# 0       FHRS  {'$map': {'input': '$longitude', 'as': 'val', ...
# 1       FHRS  {'$map': {'input': '$longitude', 'as': 'val', ...
# 2       FHRS  {'$map': {'input': '$longitude', 'as': 'val', ...
# 3       FHRS  {'$map': {'input': '$longitude', 'as': 'val', ...
# 4       FHRS  {'$map': {'input': '$longitude', 'as': 'val', ...
#
#       Distance NewRatingPending  \
# 0  4618.860470            False
# 1  4619.497868            False
# 2  4623.910775            False
# 3  4624.029886            False
# 4  4624.092761            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links  \
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
#
#                                            longitude  \
# 0  {'$map': {'input': '$longitude', 'as': 'val', ...
# 1  {'$map': {'input': '$longitude', 'as': 'val', ...
# 2  {'$map': {'input': '$longitude', 'as': 'val', ...
# 3  {'$map': {'input': '$longitude', 'as': 'val', ...
# 4  {'$map': {'input': '$longitude', 'as': 'val', ...
#
#                                             latitude
# 0  {'$map': {'input': '$latitude', 'as': 'val', '...
# 1  {'$map': {'input': '$latitude', 'as': 'val', '...
# 2  {'$map': {'input': '$latitude', 'as': 'val', '...
# 3  {'$map': {'input': '$latitude', 'as': 'val', '...
# 4  {'$map': {'input': '$latitude', 'as': 'val', '...
#
# [5 rows x 30 columns]

# %%
# Display the number of rows in the DataFrame
print(len(query2_df))

# Display the first 10 rows of the DataFrame
query2_df.head(10)
# Out:
# 1192
#                         _id   FHRSID  ChangesByServerID  \
# 0  63d17220d1aa1709dbbc06b2   836424                  0
# 1  63d17220d1aa1709dbbc07dc  1009559                  0
# 2  63d17220d1aa1709dbbc1113   632021                  0
# 3  63d17220d1aa1709dbbc1130   959816                  0
# 4  63d17220d1aa1709dbbc1155  1290095                  0
# 5  63d17220d1aa1709dbbc1167  1048649                  0
# 6  63d17220d1aa1709dbbc1434  1171761                  0
# 7  63d17220d1aa1709dbbc181b   764434                  0
# 8  63d17220d1aa1709dbbc1c87   512509                  0
# 9  63d17220d1aa1709dbbc1e11  1262211                  0
#
#   LocalAuthorityBusinessID                   BusinessName  \
# 0          15/500750/MIXED                      Nats Snax
# 1           17/500586/FOOD       Sittingbourne Rugby Club
# 2             PI/000023516                  Welcome House
# 3          17/500226/MIXED  The Food Warehouse By Iceland
# 4          20/500534/MIXED                  Home Bargains
# 5             PI/000250342                   Burger Babes
# 6            19/00108/FOOD                       RBLI Ltd
# 7          15/00187/RETAIL                          Argos
# 8            12/00251/GARS    London Road Service Station
# 9          20/00075/CAFESN                 Lila's Spa Ltd
#
#               BusinessType  BusinessTypeID                 AddressLine1  \
# 0           Mobile caterer            7846                   Burger Van
# 1        Pub/bar/nightclub            7843      Gore Court Cricket Club
# 2          Caring Premises               5  Welcome House - Leeza Court
# 3        Retailers - other            4613                      Unit 1B
# 4        Retailers - other            4613                       Unit 3
# 5           Mobile caterer            7846            Jackies Snack Bar
# 6          Caring Premises               5            Gavin Astor House
# 7        Retailers - other            4613                     Homebase
# 8        Retailers - other            4613                           BP
# 9  Restaurant/Cafe/Canteen               1                       Unit C
#
#                    AddressLine2           AddressLine3  ...  \
# 0                        Wickes            London Road  ...
# 1                The Grove Park            London Road  ...
# 2                   Leeza Court          9 London Road  ...
# 3       London Road Retail Park            London Road  ...
# 4       London Road Retail Park            London Road  ...
# 5              Playfootball Net            London Road  ...
# 6  Royal British Legion Village            London Road  ...
# 7                   Argos Stand         85 London Road  ...
# 8                Petrol Station  600 - 602 London Road  ...
# 9          Chalkwell Park House        700 London Road  ...
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 5  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...       FHRS
# 6  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 7  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 9  {'Hygiene': 0, 'Structural': 10, 'ConfidenceIn...       FHRS
#
#                                              geocode RightToReply  \
# 0  {'$map': {'input': '$longitude', 'as': 'val', ...
# 1  {'$map': {'input': '$longitude', 'as': 'val', ...
# 2  {'$map': {'input': '$longitude', 'as': 'val', ...
# 3  {'$map': {'input': '$longitude', 'as': 'val', ...
# 4  {'$map': {'input': '$longitude', 'as': 'val', ...
# 5  {'$map': {'input': '$longitude', 'as': 'val', ...
# 6  {'$map': {'input': '$longitude', 'as': 'val', ...
# 7  {'$map': {'input': '$longitude', 'as': 'val', ...
# 8  {'$map': {'input': '$longitude', 'as': 'val', ...
# 9  {'$map': {'input': '$longitude', 'as': 'val', ...
#
#       Distance NewRatingPending  \
# 0  4618.860470            False
# 1  4619.497868            False
# 2  4623.910775            False
# 3  4624.029886            False
# 4  4624.092761            False
# 5  4624.098698            False
# 6  4625.734779            False
# 7  4626.678114            False
# 8  4627.571850            False
# 9  4627.751840            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links  \
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'https://api.ratings....
# 8  [{'rel': 'self', 'href': 'https://api.ratings....
# 9  [{'rel': 'self', 'href': 'https://api.ratings....
#
#                                            longitude  \
# 0  {'$map': {'input': '$longitude', 'as': 'val', ...
# 1  {'$map': {'input': '$longitude', 'as': 'val', ...
# 2  {'$map': {'input': '$longitude', 'as': 'val', ...
# 3  {'$map': {'input': '$longitude', 'as': 'val', ...
# 4  {'$map': {'input': '$longitude', 'as': 'val', ...
# 5  {'$map': {'input': '$longitude', 'as': 'val', ...
# 6  {'$map': {'input': '$longitude', 'as': 'val', ...
# 7  {'$map': {'input': '$longitude', 'as': 'val', ...
# 8  {'$map': {'input': '$longitude', 'as': 'val', ...
# 9  {'$map': {'input': '$longitude', 'as': 'val', ...
#
#                                             latitude
# 0  {'$map': {'input': '$latitude', 'as': 'val', '...
# 1  {'$map': {'input': '$latitude', 'as': 'val', '...
# 2  {'$map': {'input': '$latitude', 'as': 'val', '...
# 3  {'$map': {'input': '$latitude', 'as': 'val', '...
# 4  {'$map': {'input': '$latitude', 'as': 'val', '...
# 5  {'$map': {'input': '$latitude', 'as': 'val', '...
# 6  {'$map': {'input': '$latitude', 'as': 'val', '...
# 7  {'$map': {'input': '$latitude', 'as': 'val', '...
# 8  {'$map': {'input': '$latitude', 'as': 'val', '...
# 9  {'$map': {'input': '$latitude', 'as': 'val', '...
#
# [10 rows x 30 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
#Parameters:
    #RatingValue = 5
    #Sort by lowest hygiene score (ascending?)
    #Nearest to new restarant added in pt 1, use geocode

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
#Print coordinates of Penang Flavors to search
penang_query = {"BusinessName":"Penang Flavours"}
penang_doc = collection.find(penang_query)
print(list(penang_doc))
# Out:
# [{'_id': ObjectId('63d18ab8e5aca93392a2cd8a'), 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'Penang Flavours', 'AddressLine2': '146A Plumstead Rd', 'AddressLine3': 'London', 'AddressLine4': '', 'PostCode': 'SE18 7DY', 'Phone': '', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''}, 'SchemeType': 'FHRS', 'geocode': {'$map': {'input': '$longitude', 'as': 'val', 'in': {'$toDecimal': '$$val'}}, 'longitude': None, 'latitude': None}, 'RightToReply': '', 'Distance': 4623.972328074718, 'NewRatingPending': True, 'longitude': {'$map': {'input': '$longitude', 'as': 'val', 'in': {'$toDecimal': '$$val'}}}, 'latitude': {'$map': {'input': '$latitude', 'as': 'val', 'in': {'$toDecimal': '$$val'}}}}, {'_id': ObjectId('63d18d9ce5aca93392a2cd8b'), 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': '', 'AddressLine1': 'Penang Flavours', 'AddressLine2': '146A Plumstead Rd', 'AddressLine3': 'London', 'AddressLine4': '', 'PostCode': 'SE18 7DY', 'Phone': '', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''}, 'SchemeType': 'FHRS', 'geocode': {'$map': {'input': '$longitude', 'as': 'val', 'in': {'$toDecimal': '$$val'}}, 'longitude': None, 'latitude': None}, 'RightToReply': '', 'Distance': 4623.972328074718, 'NewRatingPending': True, 'longitude': {'$map': {'input': '$longitude', 'as': 'val', 'in': {'$toDecimal': '$$val'}}}, 'latitude': {'$map': {'input': '$latitude', 'as': 'val', 'in': {'$toDecimal': '$$val'}}}}, {'_id': ObjectId('63d2b35d5b550be8f5b2f2d5'), 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': '', 'AddressLine1': 'Penang Flavours', 'AddressLine2': '146A Plumstead Rd', 'AddressLine3': 'London', 'AddressLine4': '', 'PostCode': 'SE18 7DY', 'Phone': '', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.08384000'), 'latitude': Decimal128('51.49014200')}, 'RightToReply': '', 'Distance': 4623.972328074718, 'NewRatingPending': True}]

# %%
#Variables as parameters to search within 0.01 degree on either side of the latitude and longitude
degree_search = 0.01
p_latitude = 51.49014200
p_longitude = 0.08384000

# %%
# Build the aggregation pipeline


#Count the number of documents, grouped by "RatingValue" and "BusinessName"
group_query = {'$group': {'_id': {"RatingValue": "$RatingValue",
                                  "BusinessName": "$BusinessName"}, 
                          'count': { '$sum': 1 }
                         }
              }

#Limit to only "5" rating value
match_query = {'$match': {'_id.RatingValue': "5"}}

#Sort by BusinessName in alphabetical order,then count in ascending order
sort_values = {'$sort': { '_id.BusinessName': 1, 'scores.Hygiene': 1}}

# Use $geoNear stage for sorting based on distance
degree_search = 0.01
latitude = p_latitude
longitude = p_longitude
geo_near = {'$geoNear': {
        "near": {"type": "Point", "coordinates": [longitude, latitude]},
        "minDistance": -degree_search,
        "maxDistance": degree_search,
        "distanceField": "Distance",
        "spherical": True
    }
    }

# Limit the number of documents to 5
limit_query = {'$limit': 5}

# Put the pipeline together
pipeline = [group_query, match_query, sort_values]

# %%
# Run the pipeline, save the results to a variable
agg_results = list(collection.aggregate(pipeline))

# Print the number of documents in the result
print(len(agg_results))
# Out:
# 21485

# %%
#Print the first 10 results
first_ten = agg_results[:10]
print(first_ten)
# Out:
# [{'_id': {'RatingValue': '5', 'BusinessName': '#Chill And Waves'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': "'R'Jac's"}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '1 Oast Cottages B&B'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '1 The Avenue'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '1-3 Simon Campion Court'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '10 Till 10'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '10 to 12 Folkestone'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '101 Social Club'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '1066 Cafe & Bakery'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '1066 Cafe Kitchen'}, 'count': 1}]

# %%
#Print pipeline results
print(agg_results)
# Out:
# [{'_id': {'RatingValue': '5', 'BusinessName': '#Chill And Waves'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': "'R'Jac's"}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '1 Oast Cottages B&B'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '1 The Avenue'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '1-3 Simon Campion Court'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '10 Till 10'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '10 to 12 Folkestone'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '101 Social Club'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '1066 Cafe & Bakery'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '1066 Cafe Kitchen'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '1066 Coffee House'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '11 Park Avenue'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '124 (Essex) Transport Squadron Rlc Army Reserve Centre'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '129 Cafe Bar'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '13 Barfields'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '14 Forty FM Services - Compass Group'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '15 Connaught Hill'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '15 Grosvenor'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '15 Queen Street'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '17 Wilmington Square'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '180 Sports Bar'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '1917 Chill Cafe'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '1:1 Diet By Cambridge Weight Plan - Tinette Weinman'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '1st Bed Guest House'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '1st Friends Day Nursery'}, 'count': 2}, {'_id': {'RatingValue': '5', 'BusinessName': '1st Harold Hill Scout Group'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '1st Herne Bay Scout Group'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '2 Hearts Catering'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '2 Js Snack Bar - Mobile'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '20 Albert Road'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '222 Coffee Shop'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '23.5 Degrees TA Starbucks'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '255 Broadway Staff Restaurant'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': "2J's Pre School Ltd"}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': "2J's Pre-School"}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '2MT Caffe'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '3 PWRR'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '300 Degrees'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '360 Play Basildon'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '363 Coffee Lounge'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '3DM Wine'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '3Nutrition Lounge'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '3rd Royal Eltham Scouts'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '4 Continents Store'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '4 Continents Stores'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '4 Spences Lane B & B'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '40 Grosvenor Drive'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '47 Bar & Restaurant'}, 'count': 1}, {'_id': {'RatingValue': '5', 'BusinessName': '49 Mortimer Street'}, 'count': ...

# %%
# Convert result to Pandas DataFrame
pipeline_df = pd.DataFrame(list(agg_results))
pipeline_df.set_index('_id')
pipeline_df.head()
# Out:
#                                                  _id  count
# 0  {'RatingValue': '5', 'BusinessName': '#Chill A...      1
# 1   {'RatingValue': '5', 'BusinessName': ''R'Jac's'}      1
# 2  {'RatingValue': '5', 'BusinessName': '1 Oast C...      1
# 3  {'RatingValue': '5', 'BusinessName': '1 The Av...      1
# 4  {'RatingValue': '5', 'BusinessName': '1-3 Simo...      1

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# %%
# Build the aggregation pipeline

# Only establishments with hygiene score = 0
match_query2 = {'$match': {'scores.Hygiene': 0}}

#Group matches by LocalAuthority
group_query2 = {'$group': {'_id': {"LocalAuthority": "$LocalAuthorityName"}, 
                          'count': { '$sum': 1 }
                         }
              }

# Sort by count in descending order
sort_query2 = {'$sort': { 'count': -1 }}

# Put the pipeline together
pipeline2 = [match_query2, group_query2, sort_query2]

# %%
# Run the pipeline, save the results to a variable
agg_results2 = list(collection.aggregate(pipeline2))

# Print the number of documents in the result
print(len(agg_results2))
# Out:
# 55

# %%
#Print the first 10 results
first_ten = agg_results2[:10]
print(first_ten)
# Out:
# [{'_id': {'LocalAuthority': 'Thanet'}, 'count': 1130}, {'_id': {'LocalAuthority': 'Greenwich'}, 'count': 882}, {'_id': {'LocalAuthority': 'Maidstone'}, 'count': 713}, {'_id': {'LocalAuthority': 'Newham'}, 'count': 711}, {'_id': {'LocalAuthority': 'Swale'}, 'count': 686}, {'_id': {'LocalAuthority': 'Chelmsford'}, 'count': 680}, {'_id': {'LocalAuthority': 'Medway'}, 'count': 672}, {'_id': {'LocalAuthority': 'Bexley'}, 'count': 607}, {'_id': {'LocalAuthority': 'Southend-On-Sea'}, 'count': 586}, {'_id': {'LocalAuthority': 'Tendring'}, 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
pipeline2_df = pd.DataFrame(list(agg_results2))
pipeline2_df.set_index("count")
pipeline2_df.head()
# Out:
#                                _id  count
# 0     {'LocalAuthority': 'Thanet'}   1130
# 1  {'LocalAuthority': 'Greenwich'}    882
# 2  {'LocalAuthority': 'Maidstone'}    713
# 3     {'LocalAuthority': 'Newham'}    711
# 4      {'LocalAuthority': 'Swale'}    686

# %%
# Display the number of rows in the DataFrame

print(len(pipeline2_df))

# Display the first 10 rows of the DataFrame
pipeline2_df.head(10)
# Out:
# 55
#                                      _id  count
# 0           {'LocalAuthority': 'Thanet'}   1130
# 1        {'LocalAuthority': 'Greenwich'}    882
# 2        {'LocalAuthority': 'Maidstone'}    713
# 3           {'LocalAuthority': 'Newham'}    711
# 4            {'LocalAuthority': 'Swale'}    686
# 5       {'LocalAuthority': 'Chelmsford'}    680
# 6           {'LocalAuthority': 'Medway'}    672
# 7           {'LocalAuthority': 'Bexley'}    607
# 8  {'LocalAuthority': 'Southend-On-Sea'}    586
# 9         {'LocalAuthority': 'Tendring'}    542
